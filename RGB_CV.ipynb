# %% [markdown]
# <a href="https://colab.research.google.com/github/atulcoin/session-in-django/blob/master/RGB_CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img=Image.open('/content/IMG_20200625_175701_61_1_80.jpg')

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_arr = np.asarray(img)

# %%
type(img_arr)
# Out:
# numpy.ndarray

# %%
img_arr.shape
# Out:
# (1952, 1464, 3)

# %%
plt.imshow(img_arr)

# %%
img1=img_arr.copy()

# %%
#RGB 0 means RED ok
img1[:,:,0]
# Out:
# array([[159, 161, 166, ..., 215, 215, 215],
#        [156, 163, 167, ..., 214, 215, 215],
#        [155, 160, 164, ..., 214, 215, 215],
#        ...,
#        [  2,   2,   2, ...,   0,   0,   1],
#        [  2,   2,   2, ...,   0,   0,   1],
#        [  1,   1,   2, ...,   0,   0,   1]], dtype=uint8)

# %%
# due to some color blind matplt use this 
plt.imshow(img1[:,:,0])

# %%
# here we have make Green and Blue as zero so only dimension left is Red
img1[:,:,1]=0
img1[:,:,2]=0

# %%
plt.imshow(img1)

# %%
img1=img_arr.copy()
img1[:,:,0]=0
img1[:,:,2]=0
plt.imshow(img1)

# %%
img1=img_arr.copy()
img1[:,:,0]=0
img1[:,:,1]=0
plt.imshow(img1)

# %% [markdown]
# # New Section
# Open Cv Updated uses

# %%
import cv2
